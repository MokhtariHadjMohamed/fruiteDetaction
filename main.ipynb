# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.3.235

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open an image
img = Image.open("dataset/Training/Apple Braeburn/0_100.jpg")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from ultralytics import YOLO

# create model from pretrained YOLOv8n
model = YOLO("yolo11s.pt")

# train on your dataset
model.train(
    data="dataset.yaml",  # contains paths & class names
    epochs=60,
    imgsz=10000,
    batch=16,
)
